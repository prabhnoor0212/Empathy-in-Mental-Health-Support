# %%
cp -R /content/drive/MyDrive/Empathy-in-Mental-Health-Support/* /content/

# %%
! pip3 install transformers
# Out:
# ...
#      |████████████████████████████████| 2.2MB 4.2MB/s
# ...
#      |████████████████████████████████| 3.3MB 52.1MB/s
# ...
#      |████████████████████████████████| 870kB 45.0MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=05808d9bdb1f80672078e826c8a56184e6d663dca85b582da65158a853b9489c
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# ...

# %% [markdown]
# interpretations (my run)

# %%
# !python -m src.run
# Out:
# 2021-03-19 17:20:31.059812: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# Explorations (my run)

# %%
# !python -m src.run
# Out:
# 2021-03-19 16:59:25.083671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %%
##simple
Emapthy Accuracy: 0.9266
Emapthy F1: 0.6804
Rationale F1:  0.6883
Rationale IOU: 0.8088

##author run
Accuracy-Empathy: 0.9116
macro_f1_empathy: 0.6594
macro_f1_rationale: 0.7103
IOU-F1-Rationale: 0.8343

##multi-head attention
Emapthy Accuracy: 0.9219
Emapthy F1: 0.6769
Rationale F1:  0.6828
Rationale IOU: 0.7991

## Talking Head 
Emapthy Accuracy: 0.9266
Emapthy F1: 0.6768
Rationale F1:  0.6989
Rationale IOU: 0.7419

## dense synthesizer
Emapthy Accuracy: 0.9172
Emapthy F1: 0.6656
Rationale F1:  0.6845
Rationale IOU: 0.5608

## all
Emapthy Accuracy: 0.9203
Emapthy F1: 0.6689
Rationale F1:  0.6996
Rationale IOU: 0.8200

# %% [markdown]
# Emotional Reactions (my run)

# %%
# !python -m src.run
# Out:
# 2021-03-19 17:01:59.122737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %%
##simple
Emapthy Accuracy: 0.7911
Emapthy F1: 0.7366
Rationale F1:  0.5358
Rationale IOU: 0.5643

##author
Accuracy-Empathy: 0.7998
macro_f1_empathy: 0.7508
macro_f1_rationale: 0.5420
IOU-F1-Rationale: 0.6012

## multi head attention
Emapthy Accuracy: 0.7974
Emapthy F1: 0.7287
Rationale F1:  0.5594
Rationale IOU: 0.5900


## Talking Head 
Emapthy Accuracy: 0.8052
Emapthy F1: 0.7536
Rationale F1:  0.5650
Rationale IOU: 0.5896

## dense synthesizer
Emapthy Accuracy: 0.7927
Emapthy F1: 0.7541
Rationale F1:  0.5297
Rationale IOU: 0.5825

## all
Emapthy Accuracy: 0.7990
Emapthy F1: 0.7706
Rationale F1:  0.5456
Rationale IOU: 0.5924

# %%
cp -R /content/drive/MyDrive/Empathy-Mental-Health/* /content/

# %% [markdown]
# Interpretations (Author run)

# %%
# !python3 src/train.py \
	--train_path=dataset/train.csv \
	--lr=2e-5 \
	--batch_size=32 \
	--lambda_EI=1.0 \
	--lambda_RE=0.5 \
    --dev_path=dataset/val.csv\
    --test_path=dataset/test.csv\
    --do_validation\
    --do_test\
	--save_model\
	--save_model_path=output/sample.pth \
# Out:
# Streaming output truncated to the last 5000 lines.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# ...

# %% [markdown]
# Explorations (Author run)

# %%
# !python3 src/train.py \
	--train_path=dataset/train.csv \
	--lr=2e-5 \
	--batch_size=32 \
	--lambda_EI=1.0 \
	--lambda_RE=0.5 \
    --dev_path=dataset/val.csv\
    --test_path=dataset/test.csv\
    --do_validation\
    --do_test\
	--save_model\
	--save_model_path=output/sample.pth \
# Out:
# Streaming output truncated to the last 5000 lines.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# ...

# %% [markdown]
# Emotional Reactions (Author run)

# %%
# !python3 src/train.py \
	--train_path=dataset/train.csv \
	--lr=2e-5 \
	--batch_size=32 \
	--lambda_EI=1.0 \
	--lambda_RE=0.5 \
    --dev_path=dataset/val.csv\
    --test_path=dataset/test.csv\
    --do_validation\
    --do_test\
	--save_model\
	--save_model_path=output/sample.pth \
# Out:
# Streaming output truncated to the last 5000 lines.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# Keyword arguments {'return_attention_masks': True} not recognized.
# ...

# %% [markdown]
# # Stretch Goal

# %% [markdown]
# #1. Multi Head Attention

# %% [markdown]
# Interpretations

# %%
# !python -m src.run
# Out:
# 2021-03-19 17:27:29.934582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# Explorations

# %%
# !python -m src.run
# Out:
# 2021-03-19 17:31:44.959785: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# Emotional Reactions

# %%
# !python -m src.run
# Out:
# 2021-03-19 17:36:07.989299: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# #2. Talking Heads Attention

# %% [markdown]
# interpretations

# %%
# !python -m src.run
# Out:
# 2021-03-22 16:06:45.463078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# explorations

# %%
# !python -m src.run
# Out:
# 2021-03-22 15:59:52.884339: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# emotional reactions

# %%
# !python -m src.run
# Out:
# 2021-03-22 16:15:25.759556: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# #3. Dense Synthesizer

# %% [markdown]
# interpretations

# %%
# !python -m src.run
# Out:
# 2021-03-22 17:05:31.383927: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# explorations

# %%
# !python -m src.run
# Out:
# 2021-03-22 17:38:05.615697: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# emotional-reactions

# %%
# !python -m src.run
# Out:
# 2021-03-22 17:44:00.147338: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# # 4. Multi Head + Talking Head + Synthesizer

# %% [markdown]
# interpretations

# %%
# !python -m src.run
# Out:
# 2021-03-22 16:39:25.453589: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# explorations

# %%
# !python -m src.run
# Out:
# 2021-03-22 16:52:15.809532: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# emotional-reactions

# %% [markdown]
# note : add drop layer and use following values for params
#
# _synth_weight = 0.1 #_talking_weight = 0.5
#
#
# logits_rationales = self.rationale_classification(self.drop_layer(response_context_embs))

# %%
# !python -m src.run
# Out:
# 2021-03-22 17:29:38.705394: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# ...

# %% [markdown]
# # Model Save Load Testing

# %%
#!python -m src.train --model_write_path="output/out.pth"

# %%
#!python -m src.eval --model_path="output/out.pth"
